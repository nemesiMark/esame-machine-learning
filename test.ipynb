# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

path = "https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/immobili.csv"
df = pd.read_csv(path)
df
# Out:
#         crim    zn  indus chas    nox     rm   age     dis  rad  tax ptratio  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2    4.09    1  296    15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671    2  242    17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671    2  242    17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622    3  222    18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622    3  222    18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ...  ...     ...
# 502  0.04527   0.0  11.93    0  0.573   6.12  76.7  2.2875    1  273    21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675    1  273    21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889    1  273    21.0
# 505  0.04741   0.0  11.93    0  0.573   6.03  80.8   2.505    1  273    21.0
# 506       is   not      a   ro     ck     et    sc      ie  nce    i      sn
#
#           b lstat  medv
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     507 non-null    object
#  1   zn       507 non-null    object
#  2   indus    507 non-null    object
#  3   chas     507 non-null    object
#  4   nox      507 non-null    object
#  5   rm       507 non-null    object
#  6   age      507 non-null    object
#  7   dis      507 non-null    object
#  8   rad      507 non-null    object
#  9   tax      507 non-null    object
#  10  ptratio  507 non-null    object
#  11  b        507 non-null    object
#  12  lstat    507 non-null    object
#  13  medv     507 non-null    object
# dtypes: object(14)
# memory usage: 55.6+ KB

# %%
# elimino l'ultima riga 
df = df.iloc[:-1,:]
df
# Out:
#         crim    zn  indus chas    nox     rm   age     dis rad  tax ptratio  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2    4.09   1  296    15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242    17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242    17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222    18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222    18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ..  ...     ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786   1  273    21.0
# 502  0.04527   0.0  11.93    0  0.573   6.12  76.7  2.2875   1  273    21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675   1  273    21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889   1  273    21.0
# 505  0.04741   0.0  11.93    0  0.573   6.03  80.8   2.505   1  273    21.0
#
#           b lstat  medv
# 0     396.9  4.98  24.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    object
#  1   zn       506 non-null    object
#  2   indus    506 non-null    object
#  3   chas     506 non-null    object
#  4   nox      506 non-null    object
#  5   rm       506 non-null    object
#  6   age      506 non-null    object
#  7   dis      506 non-null    object
#  8   rad      506 non-null    object
#  9   tax      506 non-null    object
#  10  ptratio  506 non-null    object
#  11  b        506 non-null    object
#  12  lstat    506 non-null    object
#  13  medv     506 non-null    object
# dtypes: object(14)
# memory usage: 55.5+ KB

# %%
# converto in float tutte le colonne
df = df.astype(float)

# %%
# rinomino la colonna medv in price
df = df.rename(columns={'medv': 'price'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    float64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    float64
#  9   tax      506 non-null    float64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
df.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# crim     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# zn       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# indus    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# chas     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# nox      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# rm       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# age      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# dis      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# rad      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# tax      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# ptratio  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# b        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# ...

# %%
df.isnull().sum() # per ogni colonna verifico valori nulli
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# price      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

plt.figure(figsize=(12, 9)) 
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
# Ho scelto un trashold da 0.4
# Colonne scelte: 'indus','nox','rm','tax','ptratio','lstat'
# Colonne droppate: ['crim','zn','chas','age','dis','rad','b']

# %%
## 1 - Declare Features and target

X = df.drop(columns=['crim','zn','chas','age','dis','rad','b', 'price'])
y = df['price']

# %%
X
# Out:
#      indus    nox     rm    tax  ptratio  lstat
# 0     2.31  0.538  6.575  296.0     15.3   4.98
# 1     7.07  0.469  6.421  242.0     17.8   9.14
# 2     7.07  0.469  7.185  242.0     17.8   4.03
# 3     2.18  0.458  6.998  222.0     18.7   2.94
# 4     2.18  0.458  7.147  222.0     18.7   5.33
# ..     ...    ...    ...    ...      ...    ...
# 501  11.93  0.573  6.593  273.0     21.0   9.67
# 502  11.93  0.573  6.120  273.0     21.0   9.08
# 503  11.93  0.573  6.976  273.0     21.0   5.64
# 504  11.93  0.573  6.794  273.0     21.0   6.48
# 505  11.93  0.573  6.030  273.0     21.0   7.88
#
# [506 rows x 6 columns]

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: price, Length: 506, dtype: float64

# %%
## 2 -suddividere il problema in Training e Test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.2, 
                                                    random_state = 667
                                                    )

# %%
## 3 - Creare ed allenare il modello (fit) sulla parte di training
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 7.98866435e-02, -6.91561451e-01,  4.48732506e+00, -4.33468005e-03,
#        -8.13107410e-01, -6.07236385e-01])

# %%
model.intercept_
# Out:
# 18.159196138069614

# %%
## 4 - creare la predizione sulla parte di TEST
y_pred = model.predict(X_test) #on Test set

# %%
## 5 -  Misurare l'errore del mio modello
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

r2score = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)

print('R2_score: ', r2score)
print('MAE: ', mae)
print('MSE: ', mse)
print('RMSE: ', rmse)
# Out:
# R2_score:  0.5981576682618854
# MAE:  3.994290641317075
# MSE:  35.94553197170562
# RMSE:  5.995459279463552

# %%
import numpy as np
import matplotlib.pyplot as plt
length = y_pred.shape[0]
k = np.linspace(0,length,length)

plt.figure(figsize=(10,7))
plt.plot(k,y_test, label="Allenata")
plt.plot(k,y_pred, label="Previsione")
plt.legend(loc=2)

# %%
import mlem
#Save model

mlem.api.save(model,
              'model_', # model_.mlem
              sample_data = X_train #features
              )
# Out:
# MlemModel(location=Location(path='c:/Users/ifoa/Desktop/esame-machine-learning/model_.mlem', project=None, rev=None, uri='file://c:/Users/ifoa/Desktop/esame-machine-learning/model_.mlem', project_uri=None, fs=<fsspec.implementations.local.LocalFileSystem object at 0x000001B2D6D57C90>), params={}, artifacts={'data': LocalArtifact(uri='model_', size=629, hash='9f9efaaf3159971fd49cf0ccfae1d7b6')}, requirements=Requirements(__root__=[InstallableRequirement(module='sklearn', version='1.2.2', package_name='scikit-learn', extra_index=None, source_url=None, vcs=None, vcs_commit=None), InstallableRequirement(module='pandas', version='1.5.0', package_name=None, extra_index=None, source_url=None, vcs=None, vcs_commit=None), InstallableRequirement(module='numpy', version='1.24.2', package_name=None, extra_index=None, source_url=None, vcs=None, vcs_commit=None)]), processors_cache={'model': SklearnModel(model=LinearRegression(), io=SimplePickleIO(), methods={'predict': Signature(name='predict', a
# ...

# %%
## Load Model
# verifico che il modello funziona caricandolo e usandolo

new_model = mlem.api.load('model_.mlem')

new_model.predict(X_test)
# Out:
# array([21.96104557, 20.86228063, 30.69726369,  6.81372338, 22.55286536,
#        20.17952498, 41.17074949, 34.48933718, 16.67322084, 23.02160289,
#        35.65030225, 11.32634366, 14.07314394, 21.96335231, 27.86733327,
#        18.89724161, 14.5284554 , 15.97798478, 25.5150016 , 23.20604061,
#        22.29480135, 12.3016949 , 20.44586519, 12.03049402, 18.21958311,
#        31.13224069, 27.00935047, 33.19266776, 17.04285591, 25.88994186,
#        28.92101078, 37.00457421, 32.14184944, 21.6722149 ,  5.35984484,
#        22.85891268, 29.5427554 , 19.00936005, 20.58007886, 37.40540092,
#        -4.65669973, 21.4251038 , 21.27642331, 26.14032154, 30.36218443,
#        26.9903172 , 38.0872794 , 27.94042515, 19.4350953 , 19.67464129,
#        32.05151056, 18.83144436, 29.09731602, 20.3859275 , 30.31140843,
#        20.78540116, 22.20529377,  0.73272234, 20.65157167, 24.48399117,
#        22.70512649, 19.20240869, 30.44324891, 16.3027934 , 20.91191641,
# ...
